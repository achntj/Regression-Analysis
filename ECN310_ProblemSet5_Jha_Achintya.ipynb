# %% [markdown]
# # Problem Set 5: Multivariate Regressions 2: Categorical Variables and Interaction Terms
#
# ### Summary and Motivation
# This problem sets continues practing with multiariate regressions. And it focuses on enhancing students' understanding of multivariate regression by incorporating categorical variables, dummy variables, and interaction terms. Using the NLSY97 dataset, students will learn to handle complex data structures and interpret the impacts of categorical variables and their interactions on dependent variables. This problem set aims to provide practical experience in Python, reinforcing the theoretical concepts learned in class.
#
#
# ### Instructions
# The dataset, data_NLSY97v2, are sourced from the NLSY97, a representative national database of individuals born in the early 1980s in the United States. Below are some variables we will use:
# - educ: number of years of education completed
# - annual_income: annual income that these individuals earned as adults
# - TotalWeeksExp: Total weeks of work experience of the individual
# - gender: denotes the gender of the individual
# - minority: 1 if the individual belongs to a minority group, 0 otherwise.
# - m_college: 1 if the individual’s mother has a college degree, 0 otherwise.
# - family income: Annual family income when these individuals were teenagers, reported in thousands.
# - gpain8: GPA in 8th grade.
# - retention: 1 if the individual was required to repeat a grade during middle school, 0 otherwise.
#
# Columns of scores from the AFQT test.  The values are measured as standard deviations from the mean.  A value of '0' means the individual earned the average score.  A value of '-1' means the indivial earned a score one standard deviation below the average.
# - asvabAR: skills in arithmetic reasoning
# - asvabMK: skills in mathematical knowledge
# - asvabPC: skills in paragraph comprehension
# - asvabWK: skills in word knowledge
# - AFTQ: average of the above 4 scores
#
# Please follow the questions and instructions below to complete this problem set. For some questions, please write and execute Python code for data analysis in Cell mode. Comment your code to explain each step. Some questions need text discussion. Please provide a detailed discussion of your results, including interpretations and answers to questions in Raw mode.
#
# Once you have completed the assignment, save your Jupyter notebook with the following naming convention: ECN310_ProblemSetX_LastName_FirstName.ipynb (replace X with the assignment number).

# %% [markdown]
# ### Exercise 1: Load the Dataset and Libraries, Data Cleaning and Engineering
#
# 1. Load needed libraries and the dataset data_NLSY97v2.xlsx, check the info about the datframe and get descritive statistics.

# %%
# Write your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

df = pd.read_excel("data_NLSY97v2.xlsx", index_col=0)
df
# Out:
#                           educ  GPA grade 8  School Retention  Annual_Income  \
# PUBID - YTH ID CODE 1997
# 1                         16.0          3.0               0.0            NaN
# 2                         14.0          3.5               0.0       115000.0
# 3                         14.0          3.0               0.0            NaN
# 4                         12.0          4.0               0.0        45000.0
# 5                         12.0          2.5               0.0       150000.0
# ...                        ...          ...               ...            ...
# 9018                       8.0          2.0               0.0        90000.0
# 9019                      13.0          1.5               1.0        43000.0
# 9020                      14.0          3.5               0.0            NaN
# 9021                      13.0          1.5               0.0        47000.0
# 9022                      16.0          2.0               0.0        60000.0
#
#                           TotalWeeksExp  Black  Hispanic  White  m_college  \
# PUBID - YTH ID CODE 1997
# 1                                   NaN    0.0       0.0    1.0        0.0
# 2                                 965.0    0.0       1.0    0.0        0.0
# 3                                 776.0    0.0       1.0    0.0        0.0
# 4                                1008.0    0.0       1.0    0.0        0.0
# 5                                 890.0    0.0       1.0    0.0        0.0
# ...                                 ...    ...       ...    ...        ...
# 9018                              942.0    0.0       0.0    1.0        0.0
# 9019                              824.0    0.0       1.0    0.0        0.0
# 9020                              494.0    0.0       0.0    1.0        0.0
# 9021                              965.0    0.0       0.0    1.0        0.0
# 9022                             1009.0    0.0       0.0    1.0        0.0
#
#                           minority  gender  asvabAR  asvabMK  asvabPC  \
# PUBID - YTH ID CODE 1997
# 1                              0.0  female    0.066    0.707   -0.507
# 2                              1.0    male   -0.238    0.259    1.080
# 3                              1.0  female   -1.009   -0.415    0.299
# 4                              1.0  female   -0.598    0.646   -0.236
# 5                              1.0    male      NaN      NaN      NaN
# ...                            ...     ...      ...      ...      ...
# 9018                           0.0  female   -0.281   -1.036   -1.826
# 9019                           1.0    male   -0.538   -0.254   -0.259
# 9020                           0.0    male    1.434    1.153    1.683
# 9021                           0.0    male    0.301   -0.392    0.139
# 9022                           0.0  female    0.453   -0.029    0.393
#
#                           asvabWK     AFQT
# PUBID - YTH ID CODE 1997
# 1                          -0.772 -0.12650
# 2                          -0.059  0.26050
# 3                          -0.703 -0.45700
# 4                          -0.542 -0.18250
# 5                             NaN      NaN
# ...                           ...      ...
# 9018                       -0.981 -1.03100
# 9019                       -1.153 -0.55100
# 9020                        1.096  1.34150
# 9021                        0.609  0.16425
# 9022                        0.983  0.45000
#
# [8984 rows x 16 columns]

# %% [markdown]
# 2. Add a column `college` to the data set that is an indicator variable that takes on a value of 1 if students have more than 13 years of education.  _Note_: This must be correct for the next question.  Please post in the discussion if you have trouble creating this variable.

# %%
# Please write your executable code here
def college(years):
    return (1 if years > 13 else 0)

# takes value 1 if the individual completed moew than 13 years of education, 0 otherwise
df['college'] = df['educ'].apply(college)
df
# Out:
#                           educ  GPA grade 8  School Retention  Annual_Income  \
# PUBID - YTH ID CODE 1997
# 1                         16.0          3.0               0.0            NaN
# 2                         14.0          3.5               0.0       115000.0
# 3                         14.0          3.0               0.0            NaN
# 4                         12.0          4.0               0.0        45000.0
# 5                         12.0          2.5               0.0       150000.0
# ...                        ...          ...               ...            ...
# 9018                       8.0          2.0               0.0        90000.0
# 9019                      13.0          1.5               1.0        43000.0
# 9020                      14.0          3.5               0.0            NaN
# 9021                      13.0          1.5               0.0        47000.0
# 9022                      16.0          2.0               0.0        60000.0
#
#                           TotalWeeksExp  Black  Hispanic  White  m_college  \
# PUBID - YTH ID CODE 1997
# 1                                   NaN    0.0       0.0    1.0        0.0
# 2                                 965.0    0.0       1.0    0.0        0.0
# 3                                 776.0    0.0       1.0    0.0        0.0
# 4                                1008.0    0.0       1.0    0.0        0.0
# 5                                 890.0    0.0       1.0    0.0        0.0
# ...                                 ...    ...       ...    ...        ...
# 9018                              942.0    0.0       0.0    1.0        0.0
# 9019                              824.0    0.0       1.0    0.0        0.0
# 9020                              494.0    0.0       0.0    1.0        0.0
# 9021                              965.0    0.0       0.0    1.0        0.0
# 9022                             1009.0    0.0       0.0    1.0        0.0
#
#                           minority  gender  asvabAR  asvabMK  asvabPC  \
# PUBID - YTH ID CODE 1997
# 1                              0.0  female    0.066    0.707   -0.507
# 2                              1.0    male   -0.238    0.259    1.080
# 3                              1.0  female   -1.009   -0.415    0.299
# 4                              1.0  female   -0.598    0.646   -0.236
# 5                              1.0    male      NaN      NaN      NaN
# ...                            ...     ...      ...      ...      ...
# 9018                           0.0  female   -0.281   -1.036   -1.826
# 9019                           1.0    male   -0.538   -0.254   -0.259
# 9020                           0.0    male    1.434    1.153    1.683
# 9021                           0.0    male    0.301   -0.392    0.139
# 9022                           0.0  female    0.453   -0.029    0.393
#
#                           asvabWK     AFQT  college
# PUBID - YTH ID CODE 1997
# 1                          -0.772 -0.12650        1
# 2                          -0.059  0.26050        1
# 3                          -0.703 -0.45700        1
# 4                          -0.542 -0.18250        0
# 5                             NaN      NaN        0
# ...                           ...      ...      ...
# 9018                       -0.981 -1.03100        0
# 9019                       -1.153 -0.55100        0
# 9020                        1.096  1.34150        1
# 9021                        0.609  0.16425        0
# 9022                        0.983  0.45000        1
#
# [8984 rows x 17 columns]

# %% [markdown]
# 3.   Later on in the  problem set, we will take the log of experience.  Since we cannot take the log of 0, we will assume that all workers who have 0 experience have at least 1 day.
# Create another variable called `exper` that transforms the variable TotalWeeksExp into years of experience by adding 1 to TotalWeeksExp and dividing by 52.14.
#
# Hint: `df['exper'] = (df['TotalWeeksExp'] + 1)/52.14`

# %%
# Please write your executable code here
df['exper'] = (df['TotalWeeksExp'] + 1)/52.14
df
# Out:
#                           educ  GPA grade 8  School Retention  Annual_Income  \
# PUBID - YTH ID CODE 1997
# 1                         16.0          3.0               0.0            NaN
# 2                         14.0          3.5               0.0       115000.0
# 3                         14.0          3.0               0.0            NaN
# 4                         12.0          4.0               0.0        45000.0
# 5                         12.0          2.5               0.0       150000.0
# ...                        ...          ...               ...            ...
# 9018                       8.0          2.0               0.0        90000.0
# 9019                      13.0          1.5               1.0        43000.0
# 9020                      14.0          3.5               0.0            NaN
# 9021                      13.0          1.5               0.0        47000.0
# 9022                      16.0          2.0               0.0        60000.0
#
#                           TotalWeeksExp  Black  Hispanic  White  m_college  \
# PUBID - YTH ID CODE 1997
# 1                                   NaN    0.0       0.0    1.0        0.0
# 2                                 965.0    0.0       1.0    0.0        0.0
# 3                                 776.0    0.0       1.0    0.0        0.0
# 4                                1008.0    0.0       1.0    0.0        0.0
# 5                                 890.0    0.0       1.0    0.0        0.0
# ...                                 ...    ...       ...    ...        ...
# 9018                              942.0    0.0       0.0    1.0        0.0
# 9019                              824.0    0.0       1.0    0.0        0.0
# 9020                              494.0    0.0       0.0    1.0        0.0
# 9021                              965.0    0.0       0.0    1.0        0.0
# 9022                             1009.0    0.0       0.0    1.0        0.0
#
#                           minority  gender  asvabAR  asvabMK  asvabPC  \
# PUBID - YTH ID CODE 1997
# 1                              0.0  female    0.066    0.707   -0.507
# 2                              1.0    male   -0.238    0.259    1.080
# 3                              1.0  female   -1.009   -0.415    0.299
# 4                              1.0  female   -0.598    0.646   -0.236
# 5                              1.0    male      NaN      NaN      NaN
# ...                            ...     ...      ...      ...      ...
# 9018                           0.0  female   -0.281   -1.036   -1.826
# 9019                           1.0    male   -0.538   -0.254   -0.259
# 9020                           0.0    male    1.434    1.153    1.683
# 9021                           0.0    male    0.301   -0.392    0.139
# 9022                           0.0  female    0.453   -0.029    0.393
#
#                           asvabWK     AFQT  college      exper
# PUBID - YTH ID CODE 1997
# 1                          -0.772 -0.12650        1        NaN
# 2                          -0.059  0.26050        1  18.527043
# 3                          -0.703 -0.45700        1  14.902186
# 4                          -0.542 -0.18250        0  19.351745
# 5                             NaN      NaN        0  17.088608
# ...                           ...      ...      ...        ...
# 9018                       -0.981 -1.03100        0  18.085923
# 9019                       -1.153 -0.55100        0  15.822785
# 9020                        1.096  1.34150        1   9.493671
# 9021                        0.609  0.16425        0  18.527043
# 9022                        0.983  0.45000        1  19.370924
#
# [8984 rows x 18 columns]

# %% [markdown]
# 3. Create a new variable in the dataframe called `female` that takes on value of 1 if the individual is female and 0 otherwire

# %%
# write your code here
df['female'] = df['gender'].map({'female': 1, 'male': 0})
df
# Out:
#                           educ  GPA grade 8  School Retention  Annual_Income  \
# PUBID - YTH ID CODE 1997
# 1                         16.0          3.0               0.0            NaN
# 2                         14.0          3.5               0.0       115000.0
# 3                         14.0          3.0               0.0            NaN
# 4                         12.0          4.0               0.0        45000.0
# 5                         12.0          2.5               0.0       150000.0
# ...                        ...          ...               ...            ...
# 9018                       8.0          2.0               0.0        90000.0
# 9019                      13.0          1.5               1.0        43000.0
# 9020                      14.0          3.5               0.0            NaN
# 9021                      13.0          1.5               0.0        47000.0
# 9022                      16.0          2.0               0.0        60000.0
#
#                           TotalWeeksExp  Black  Hispanic  White  m_college  \
# PUBID - YTH ID CODE 1997
# 1                                   NaN    0.0       0.0    1.0        0.0
# 2                                 965.0    0.0       1.0    0.0        0.0
# 3                                 776.0    0.0       1.0    0.0        0.0
# 4                                1008.0    0.0       1.0    0.0        0.0
# 5                                 890.0    0.0       1.0    0.0        0.0
# ...                                 ...    ...       ...    ...        ...
# 9018                              942.0    0.0       0.0    1.0        0.0
# 9019                              824.0    0.0       1.0    0.0        0.0
# 9020                              494.0    0.0       0.0    1.0        0.0
# 9021                              965.0    0.0       0.0    1.0        0.0
# 9022                             1009.0    0.0       0.0    1.0        0.0
#
#                           minority  gender  asvabAR  asvabMK  asvabPC  \
# PUBID - YTH ID CODE 1997
# 1                              0.0  female    0.066    0.707   -0.507
# 2                              1.0    male   -0.238    0.259    1.080
# 3                              1.0  female   -1.009   -0.415    0.299
# 4                              1.0  female   -0.598    0.646   -0.236
# 5                              1.0    male      NaN      NaN      NaN
# ...                            ...     ...      ...      ...      ...
# 9018                           0.0  female   -0.281   -1.036   -1.826
# 9019                           1.0    male   -0.538   -0.254   -0.259
# 9020                           0.0    male    1.434    1.153    1.683
# 9021                           0.0    male    0.301   -0.392    0.139
# 9022                           0.0  female    0.453   -0.029    0.393
#
#                           asvabWK     AFQT  college      exper  female
# PUBID - YTH ID CODE 1997
# 1                          -0.772 -0.12650        1        NaN       1
# 2                          -0.059  0.26050        1  18.527043       0
# 3                          -0.703 -0.45700        1  14.902186       1
# 4                          -0.542 -0.18250        0  19.351745       1
# 5                             NaN      NaN        0  17.088608       0
# ...                           ...      ...      ...        ...     ...
# 9018                       -0.981 -1.03100        0  18.085923       1
# 9019                       -1.153 -0.55100        0  15.822785       0
# 9020                        1.096  1.34150        1   9.493671       0
# 9021                        0.609  0.16425        0  18.527043       0
# 9022                        0.983  0.45000        1  19.370924       1
#
# [8984 rows x 19 columns]

# %% [markdown]
# ### Exercise 2: A linear probability model
# In earlier problem sets, we have seend that years of education is a statistically significant determinant of annual income.  We can use the tools of multivariate regression to make inferences about the probability or likelihood that and individual attends college.
#
# 1. Using statsmodels formula notation, perform a univariate regression with `college` and the dependent variable and `female` as the independent variable. Print the results and interpret the constant and the coefficient on female.

# %%
# Write your executable code here

# I have used C() to show its a categorical / binary variable. The model produces the same results without the C() as well.

results = smf.ols("college ~ C(female)", data=df).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                college   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     84.41
# Date:                Tue, 03 Dec 2024   Prob (F-statistic):           4.92e-20
# Time:                        22:21:11   Log-Likelihood:                -6121.9
# No. Observations:                8984   AIC:                         1.225e+04
# Df Residuals:                    8982   BIC:                         1.226e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.3166      0.007     44.883      0.000       0.303       0.330
# C(female)[T.1]     0.0928      0.010      9.187      0.000       0.073       0.113
# ==============================================================================
# Omnibus:                    42631.367   Durbin-Watson:                   1.666
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1485.498
# Skew:                           0.567   Prob(JB):                         0.00
# Kurtosis:                       1.362   Cond. No.                         2.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [raw]
# Write your interpretation here
#
# The constantis equal to 0.3166. This is the predicted probability of attending college for males in this case. On average, males have a 31.66% likelihood of attending college.
#
#
# This coefficient is 0.0928 which means that females are 9.28 percentage points more likely to attend college than males, on average, holding all else constant. The p-value being less than 0.001 shows that this effect is statistically significant at most confidence levels.

# %% [markdown]
# 2. Now include the indicator variables `minority` and `m_college` in your regression. Your regession should be `college` as the dependent variable and `female`, `minority` and `m_college` as independent variables.  Run the regression and interpret the coefficients.
#
# In your interpretation, answer what the model suggests about probability a minority male whose mother has attended college has also attended college?

# %%
# Write your code here
results2 = smf.ols("college ~ C(female) + C(minority) +C(m_college)", data=df).fit()
print(results2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                college   R-squared:                       0.108
# Model:                            OLS   Adj. R-squared:                  0.108
# Method:                 Least Squares   F-statistic:                     324.3
# Date:                Tue, 03 Dec 2024   Prob (F-statistic):          9.09e-199
# Time:                        22:21:11   Log-Likelihood:                -5054.9
# No. Observations:                8014   AIC:                         1.012e+04
# Df Residuals:                    8010   BIC:                         1.015e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.2956      0.009     32.111      0.000       0.278       0.314
# C(female)[T.1]          0.1039      0.010     10.220      0.000       0.084       0.124
# C(minority)[T.1.0]     -0.0866      0.010     -8.326      0.000      -0.107      -0.066
# C(m_college)[T.1.0]     0.3641      0.014     26.062      0.000       0.337       0.391
# ==============================================================================
# Omnibus:                     8219.744   Durbin-Watson:                   1.787
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              912.467
# Skew:                           0.561   Prob(JB):                    7.25e-199
# Kurtosis:                       1.787   Cond. No.                         3.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [raw]
# Write your interpretation here
#
# The constant tells us the the predicted probability of attending college for non-minority males whose mothers did not attend college, which is 29.56%.
#
# The coefficient for "female" tells us that being female increases the probability of attending college by 10.39 percentage points, compared to males, holding other factors constant.
#
# The coefficient for "minority" tells us that belonging to a minority group decreases the probability of attending college by 8.66 percentage points, compared to non-minority individuals, holding other factors constant.
#
# The coefficient for "m_college" tells us that having a mother who attended college increases the probability of attending college by 36.41 percentage points, compared to individuals whose mothers did not attend college, holding other factors constant.
#
# Predicted Probability for a minority male whose mother has attended college has also attended college = 0.2956 − 0.0866 + 0.3641 = 0.5731 or 57.31%.

# %% [markdown]
# 3. What happens when you add the variable `White` to the regression.  Do you think it makes sense to include this variable?  Why or why not.

# %%
# Write code here (optional) you can answer the question without code.

results_ = smf.ols("college ~ C(female) + C(minority) +C(m_college) +C(White)", data=df).fit()
print(results_.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                college   R-squared:                       0.108
# Model:                            OLS   Adj. R-squared:                  0.108
# Method:                 Least Squares   F-statistic:                     242.6
# Date:                Tue, 03 Dec 2024   Prob (F-statistic):          5.19e-197
# Time:                        22:21:11   Log-Likelihood:                -5056.0
# No. Observations:                8014   AIC:                         1.012e+04
# Df Residuals:                    8009   BIC:                         1.016e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            1.222e+11   7.97e+10      1.533      0.125    -3.4e+10    2.78e+11
# C(female)[T.1]          0.1040      0.010     10.231      0.000       0.084       0.124
# C(minority)[T.1.0]  -1.222e+11   7.97e+10     -1.533      0.125   -2.78e+11     3.4e+10
# C(m_college)[T.1.0]     0.3641      0.014     26.060      0.000       0.337       0.391
# C(White)[T.1.0]     -1.222e+11   7.97e+10     -1.533      0.125   -2.78e+11     3.4e+10
# ==============================================================================
# Omnibus:                     7153.364   Durbin-Watson:                   1.788
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              894.790
# Skew:                           0.558   Prob(JB):                    5.00e-195
# Kurtosis:                       1.802   Cond. No.                     3.65e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.09e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [raw]
# Provide your explanation here
#
# No, it does not make sense to include White in this regression for several reasons. The variable minority is already in the model, including White does not add new information because the two are complements (or atleast highlt correlated) in this case. Also, both variables have exactly the same coefficient.
#
# The high correlation between White and minority inflates standard errors by a lot.
#
# Including both variables makes it harder to clearly interpret the role of racial identity in predicting college attendance.

# %% [markdown]
# ### Exercise 3: Multivariate Regression Analysis
#
# #### Linear versus logged dependend variable
#
# 1. Using statsmodels formula notation, perform a multivariate regression analysis with `Annual_Income` as the dependent variable and  `educ`, `exper`, `female`, and `AFQT` as the independent variables. A constant should be included by default.
#
# Interpret the coefficients and comment on siginifance of the coefficients in the space below.
#
# Write your code for fitting the model and print the summary of the regression model.

# %%
# Please write your executable code here
results3 = smf.ols("Annual_Income ~ educ + exper + AFQT + C(female)", data=df).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Annual_Income   R-squared:                       0.186
# Model:                            OLS   Adj. R-squared:                  0.185
# Method:                 Least Squares   F-statistic:                     217.3
# Date:                Tue, 03 Dec 2024   Prob (F-statistic):          3.83e-168
# Time:                        22:21:11   Log-Likelihood:                -47083.
# No. Observations:                3812   AIC:                         9.418e+04
# Df Residuals:                    3807   BIC:                         9.421e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept      -1.873e+04   6711.088     -2.791      0.005   -3.19e+04   -5576.327
# C(female)[T.1] -2.513e+04   1827.099    -13.756      0.000   -2.87e+04   -2.16e+04
# educ            5480.7239    450.889     12.155      0.000    4596.716    6364.732
# exper           1436.4328    228.802      6.278      0.000     987.847    1885.018
# AFQT            1.317e+04   1259.600     10.454      0.000    1.07e+04    1.56e+04
# ==============================================================================
# Omnibus:                     2604.833   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36534.420
# Skew:                           3.145   Prob(JB):                         0.00
# Kurtosis:                      16.801   Cond. No.                         159.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Provide your comments here
#
# Coefficient on intercept is -18,730 which means the predicted annual income when all other variables are zero is -$18,730. It is statistically significant (p = 0.005).
#
#
# Coefficient on female is -25,130 which means being female is associated with earning $25,130 less annually compared to males, holding other factors constant. It is statiscally significant (p < 0.001).
#
#
# Coefficient on education is 5,481 which means each additional year of education is associated with earning $5,481 more annually, holding other factors constant. It is statistically significant (p < 0.001).
#
#
# Coefficient on experience is 1,436 which means each additional year of work experience is associated with earning $1,436 more annually, holding other factors constant. It is statistically significant (p < 0.001).
#
# Coefficient on AFQT is 13,170 which means a one-unit increase in AFQT score is associated with earning $13,170 more annually, holding other factors constant. It is statistically significant (p < 0.001).

# %% [markdown]
# #### Logged variables

# %% [markdown]
# 2a. Run the regression with `log(Annual_Income)` as the dependent variable and the same independent variables, that is `educ`, `exper`, `female`, and `AFQT`. Interpret each of the coefficients and note their significance.

# %%
# write your code here
results3 = smf.ols("np.log(Annual_Income) ~ educ + exper + AFQT + C(female)", data=df).fit()
print(results3.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     np.log(Annual_Income)   R-squared:                       0.244
# Model:                               OLS   Adj. R-squared:                  0.243
# Method:                    Least Squares   F-statistic:                     307.2
# Date:                   Tue, 03 Dec 2024   Prob (F-statistic):          2.49e-229
# Time:                           22:21:11   Log-Likelihood:                -4831.4
# No. Observations:                   3812   AIC:                             9673.
# Df Residuals:                       3807   BIC:                             9704.
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          8.8999      0.103     86.336      0.000       8.698       9.102
# C(female)[T.1]    -0.4382      0.028    -15.613      0.000      -0.493      -0.383
# educ               0.0844      0.007     12.189      0.000       0.071       0.098
# exper              0.0566      0.004     16.092      0.000       0.050       0.063
# AFQT               0.1851      0.019      9.568      0.000       0.147       0.223
# ==============================================================================
# Omnibus:                     1413.979   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9176.317
# Skew:                          -1.620   Prob(JB):                         0.00
# Kurtosis:                       9.876   Cond. No.                         159.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [raw]
# Write your interpretation here
#
# Coefficient on female is -0.4382 which means being female is associated with approximately 43.82% lower annual income compared to males, holding other factors constant. It is statistically significant (p < 0.001).
#
# Coefficient on education is 0.0844 which means each additional year of education is associated with approximately 8.44% higher annual income, holding other factors constant. It is statistically significant (p < 0.001).
#
# Coefficient on experience is 0.0566 which means each additional year of work experience is associated with approximately 5.66% higher annual income, holding other factors constant. It is statistically significant (p < 0.001).
#
# Coefficient on AFQT is 0.1851 which means a one-unit increase in AFQT score is associated with approximately 18.51% higher annual income, holding other factors constant. It is statistically significant (p < 0.001).

# %% [markdown]
# 2b. Run the regression again, but this time also take the log of `exper`. That is, `educ`, `log(exper)`, `female`, and `AFQT` as independent variables and `log(Annual_Income)` as the dependent variable. .
#
# Interpret the coefficient of `log(exper)`.  Compare the $R^2$ valuesthe model with logged experience and linear experience, which do you think a better choice?

# %%
# write your code here
results4 = smf.ols("np.log(Annual_Income) ~ educ + np.log(exper) + AFQT + C(female)", data=df).fit()
print(results4.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     np.log(Annual_Income)   R-squared:                       0.201
# Model:                               OLS   Adj. R-squared:                  0.200
# Method:                    Least Squares   F-statistic:                     239.8
# Date:                   Tue, 03 Dec 2024   Prob (F-statistic):          6.35e-184
# Time:                           22:21:11   Log-Likelihood:                -4936.3
# No. Observations:                   3812   AIC:                             9883.
# Df Residuals:                       3807   BIC:                             9914.
# Df Model:                              4
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          9.2476      0.110     84.346      0.000       9.033       9.463
# C(female)[T.1]    -0.4678      0.029    -16.242      0.000      -0.524      -0.411
# educ               0.0967      0.007     13.669      0.000       0.083       0.111
# np.log(exper)      0.1494      0.023      6.423      0.000       0.104       0.195
# AFQT               0.2034      0.020     10.246      0.000       0.164       0.242
# ==============================================================================
# Omnibus:                     1526.649   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10202.336
# Skew:                          -1.763   Prob(JB):                         0.00
# Kurtosis:                      10.197   Cond. No.                         110.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [raw]
# Add your interpretation here
#
# The coefficient on log(experience) is 0.1494, which means a 1% increase in years of experience is associated with a 0.1494% increase in annual income, holding other factors constant. It is statistically significant (p < 0.001).
#
# Comparing both models, the linear experience model performs better as it has a higher R-squared value (0.244 compared to 0.201), explaining 4.3 percentage points more variation. This is also true if we compare adjusted R squared values.
#
# However I think that the logged experience model is likely a better choice because it is more intuitive that there will be a more realistic diminishing returns to experience - early years of experience tend to increase wages more than later years

# %% [markdown]
# #### Interaction Terms:
#
# 4a. Create a new variable, `female_educ` that is equal to the column `female`  multiplied by the column `educ`. This will allow us to add an interaction term to our model

# %%
# Write your executable code here
df['female_educ'] = df['female'] * df['educ']
df
# Out:
#                           educ  GPA grade 8  School Retention  Annual_Income  \
# PUBID - YTH ID CODE 1997
# 1                         16.0          3.0               0.0            NaN
# 2                         14.0          3.5               0.0       115000.0
# 3                         14.0          3.0               0.0            NaN
# 4                         12.0          4.0               0.0        45000.0
# 5                         12.0          2.5               0.0       150000.0
# ...                        ...          ...               ...            ...
# 9018                       8.0          2.0               0.0        90000.0
# 9019                      13.0          1.5               1.0        43000.0
# 9020                      14.0          3.5               0.0            NaN
# 9021                      13.0          1.5               0.0        47000.0
# 9022                      16.0          2.0               0.0        60000.0
#
#                           TotalWeeksExp  Black  Hispanic  White  m_college  \
# PUBID - YTH ID CODE 1997
# 1                                   NaN    0.0       0.0    1.0        0.0
# 2                                 965.0    0.0       1.0    0.0        0.0
# 3                                 776.0    0.0       1.0    0.0        0.0
# 4                                1008.0    0.0       1.0    0.0        0.0
# 5                                 890.0    0.0       1.0    0.0        0.0
# ...                                 ...    ...       ...    ...        ...
# 9018                              942.0    0.0       0.0    1.0        0.0
# 9019                              824.0    0.0       1.0    0.0        0.0
# 9020                              494.0    0.0       0.0    1.0        0.0
# 9021                              965.0    0.0       0.0    1.0        0.0
# 9022                             1009.0    0.0       0.0    1.0        0.0
#
#                           minority  gender  asvabAR  asvabMK  asvabPC  \
# PUBID - YTH ID CODE 1997
# 1                              0.0  female    0.066    0.707   -0.507
# 2                              1.0    male   -0.238    0.259    1.080
# 3                              1.0  female   -1.009   -0.415    0.299
# 4                              1.0  female   -0.598    0.646   -0.236
# 5                              1.0    male      NaN      NaN      NaN
# ...                            ...     ...      ...      ...      ...
# 9018                           0.0  female   -0.281   -1.036   -1.826
# 9019                           1.0    male   -0.538   -0.254   -0.259
# 9020                           0.0    male    1.434    1.153    1.683
# 9021                           0.0    male    0.301   -0.392    0.139
# 9022                           0.0  female    0.453   -0.029    0.393
#
#                           asvabWK     AFQT  college      exper  female  \
# PUBID - YTH ID CODE 1997
# 1                          -0.772 -0.12650        1        NaN       1
# 2                          -0.059  0.26050        1  18.527043       0
# 3                          -0.703 -0.45700        1  14.902186       1
# 4                          -0.542 -0.18250        0  19.351745       1
# 5                             NaN      NaN        0  17.088608       0
# ...                           ...      ...      ...        ...     ...
# 9018                       -0.981 -1.03100        0  18.085923       1
# 9019                       -1.153 -0.55100        0  15.822785       0
# 9020                        1.096  1.34150        1   9.493671       0
# 9021                        0.609  0.16425        0  18.527043       0
# 9022                        0.983  0.45000        1  19.370924       1
#
#                           female_educ
# PUBID - YTH ID CODE 1997
# 1                                16.0
# 2                                 0.0
# 3                                14.0
# 4                                12.0
# 5                                 0.0
# ...                               ...
# 9018                              8.0
# 9019                              0.0
# 9020                              0.0
# 9021                              0.0
# 9022                             16.0
#
# [8984 rows x 20 columns]

# %% [markdown]
# 4b. Return to the linear form of `exper` and add `female_educ` to the regression with the logged annual income and and comment on significance and interpetation of the coefficient `female_educ`.
#
# Your dependent variable is `log(Annual_Income)` and independent variables should be `educ` , `exper`,   `AFQT`,  `female`, `minority`, `female_educ`.  Interpet the coefficients on `educ`, `female` and `female_educ`.  _Note:_ significance is important.

# %%
# Please write your executable code here
results5 = smf.ols("np.log(Annual_Income) ~ educ + exper + AFQT + C(female) + C(minority) + female_educ", data=df).fit()
print(results5.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     np.log(Annual_Income)   R-squared:                       0.245
# Model:                               OLS   Adj. R-squared:                  0.244
# Method:                    Least Squares   F-statistic:                     198.5
# Date:                   Tue, 03 Dec 2024   Prob (F-statistic):          9.24e-220
# Time:                           22:21:12   Log-Likelihood:                -4652.9
# No. Observations:                   3680   AIC:                             9320.
# Df Residuals:                       3673   BIC:                             9363.
# Df Model:                              6
# Covariance Type:               nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              8.8773      0.135     65.834      0.000       8.613       9.142
# C(female)[T.1]        -0.3592      0.159     -2.257      0.024      -0.671      -0.047
# C(minority)[T.1.0]    -0.0092      0.031     -0.292      0.770      -0.071       0.052
# educ                   0.0869      0.009      9.423      0.000       0.069       0.105
# exper                  0.0560      0.004     15.612      0.000       0.049       0.063
# AFQT                   0.1844      0.021      8.708      0.000       0.143       0.226
# female_educ           -0.0062      0.012     -0.537      0.592      -0.029       0.016
# ==============================================================================
# Omnibus:                     1393.787   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9375.458
# Skew:                          -1.646   Prob(JB):                         0.00
# Kurtosis:                      10.092   Cond. No.                         302.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [raw]
# Please write your discussion here.
#
# Coefficient on education is 0.0869 which means for males (when female = 0), each additional year of education is associated with earning approximately 8.69% more annually, holding other factors constant. It is statistically significant (p < 0.001).
#
# Coefficient on female is -0.3592 which means for people with zero education (when educ = 0), being female is associated with earning approximately 35.92% less annually compared to males, holding other factors constant. It is statistically significant (p = 0.024).
#
# Coefficient on female_educ is -0.0062 which means the difference in returns to education between females and males is approximately -0.62 percentage points - in other words, females get a slightly lower return to education than males. However, this difference is not statistically significant (p = 0.592).

# %% [markdown]
# 4c. Create a new variable, `minority_educ` that is the column `minority` multiplied by the column `educ`

# %%
# Write your executable code here
df['minority_educ'] = df['minority'] * df['educ']
df
# Out:
#                           educ  GPA grade 8  School Retention  Annual_Income  \
# PUBID - YTH ID CODE 1997
# 1                         16.0          3.0               0.0            NaN
# 2                         14.0          3.5               0.0       115000.0
# 3                         14.0          3.0               0.0            NaN
# 4                         12.0          4.0               0.0        45000.0
# 5                         12.0          2.5               0.0       150000.0
# ...                        ...          ...               ...            ...
# 9018                       8.0          2.0               0.0        90000.0
# 9019                      13.0          1.5               1.0        43000.0
# 9020                      14.0          3.5               0.0            NaN
# 9021                      13.0          1.5               0.0        47000.0
# 9022                      16.0          2.0               0.0        60000.0
#
#                           TotalWeeksExp  Black  Hispanic  White  m_college  \
# PUBID - YTH ID CODE 1997
# 1                                   NaN    0.0       0.0    1.0        0.0
# 2                                 965.0    0.0       1.0    0.0        0.0
# 3                                 776.0    0.0       1.0    0.0        0.0
# 4                                1008.0    0.0       1.0    0.0        0.0
# 5                                 890.0    0.0       1.0    0.0        0.0
# ...                                 ...    ...       ...    ...        ...
# 9018                              942.0    0.0       0.0    1.0        0.0
# 9019                              824.0    0.0       1.0    0.0        0.0
# 9020                              494.0    0.0       0.0    1.0        0.0
# 9021                              965.0    0.0       0.0    1.0        0.0
# 9022                             1009.0    0.0       0.0    1.0        0.0
#
#                           minority  ... asvabAR  asvabMK  asvabPC  asvabWK  \
# PUBID - YTH ID CODE 1997            ...
# 1                              0.0  ...   0.066    0.707   -0.507   -0.772
# 2                              1.0  ...  -0.238    0.259    1.080   -0.059
# 3                              1.0  ...  -1.009   -0.415    0.299   -0.703
# 4                              1.0  ...  -0.598    0.646   -0.236   -0.542
# 5                              1.0  ...     NaN      NaN      NaN      NaN
# ...                            ...  ...     ...      ...      ...      ...
# 9018                           0.0  ...  -0.281   -1.036   -1.826   -0.981
# 9019                           1.0  ...  -0.538   -0.254   -0.259   -1.153
# 9020                           0.0  ...   1.434    1.153    1.683    1.096
# 9021                           0.0  ...   0.301   -0.392    0.139    0.609
# 9022                           0.0  ...   0.453   -0.029    0.393    0.983
#
#                              AFQT  college      exper  female  female_educ  \
# PUBID - YTH ID CODE 1997
# 1                        -0.12650        1        NaN       1         16.0
# 2                         0.26050        1  18.527043       0          0.0
# 3                        -0.45700        1  14.902186       1         14.0
# 4                        -0.18250        0  19.351745       1         12.0
# 5                             NaN        0  17.088608       0          0.0
# ...                           ...      ...        ...     ...          ...
# 9018                     -1.03100        0  18.085923       1          8.0
# 9019                     -0.55100        0  15.822785       0          0.0
# 9020                      1.34150        1   9.493671       0          0.0
# 9021                      0.16425        0  18.527043       0          0.0
# 9022                      0.45000        1  19.370924       1         16.0
#
#                           minority_educ
# PUBID - YTH ID CODE 1997
# 1                                   0.0
# 2                                  14.0
# 3                                  14.0
# 4                                  12.0
# 5                                  12.0
# ...                                 ...
# 9018                                0.0
# 9019                               13.0
# 9020                                0.0
# 9021                                0.0
# 9022                                0.0
#
# [8984 rows x 21 columns]

# %% [markdown]
# 4d. Add `minority_educ` to the regression. Your independent variables should be `educ` , `exper`,   `AFQT`,  `female`, `minority`, `female_educ`, `minority_educ`.  Your dependent variable is `log(Annual_Income)`
#
#
# Print the results and intepret the coefficients on `minority` and `minority_educ`. What do the coefficients suggest about the return to education for minorities?

# %%
# Write your code here
results6 = smf.ols("np.log(Annual_Income) ~ educ + exper + AFQT + C(female) + C(minority) + female_educ + minority_educ", data=df).fit()
print(results6.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     np.log(Annual_Income)   R-squared:                       0.246
# Model:                               OLS   Adj. R-squared:                  0.245
# Method:                    Least Squares   F-statistic:                     171.2
# Date:                   Tue, 03 Dec 2024   Prob (F-statistic):          7.90e-220
# Time:                           22:21:12   Log-Likelihood:                -4650.0
# No. Observations:                   3680   AIC:                             9316.
# Df Residuals:                       3672   BIC:                             9366.
# Df Model:                              7
# Covariance Type:               nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              9.0398      0.151     59.898      0.000       8.744       9.336
# C(female)[T.1]        -0.3398      0.159     -2.134      0.033      -0.652      -0.028
# C(minority)[T.1.0]    -0.3873      0.161     -2.402      0.016      -0.703      -0.071
# educ                   0.0758      0.010      7.335      0.000       0.056       0.096
# exper                  0.0557      0.004     15.534      0.000       0.049       0.063
# AFQT                   0.1843      0.021      8.708      0.000       0.143       0.226
# female_educ           -0.0077      0.012     -0.669      0.503      -0.030       0.015
# minority_educ          0.0280      0.012      2.391      0.017       0.005       0.051
# ==============================================================================
# Omnibus:                     1391.834   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9389.273
# Skew:                          -1.643   Prob(JB):                         0.00
# Kurtosis:                      10.102   Cond. No.                         334.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [raw]
# Include your discussion here
#
# Coefficient on minority is -0.3873 which means being a minority is associated with earning 38.73% less annually compared to non-minorities, holding other factors constant. It is statistically significant for most confidence levels(p = 0.016).
#
# Coefficient on minority_educ is 0.0280 which means each additional year of education for minorities is associated with earning 2.80% more annually compared to non-minorities' education returns, holding other factors constant. It is statistically significant for most confidence intervals (p = 0.017).

# %% [markdown]
# #### Exercise 4: Model Specification

# %% [markdown]
# 1. Compare all model specifications, e.g., logged dependent variable, logged independent variables, interactions, and variables to include (you can add more from the data set, if you choose), and select. the model that you think does the best job describing the effect of education on annual income. Run the regression and print the summary. _Create and run as many as you like, but only include one in your final submission_. Explain why you think it is the best.

# %%
# Please write your executable code here
results_final = smf.ols("np.log(Annual_Income) ~ np.log(educ) + exper + AFQT + C(female) + C(minority) + female_educ + minority_educ", data=df).fit()
print(results_final.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     np.log(Annual_Income)   R-squared:                       0.244
# Model:                               OLS   Adj. R-squared:                  0.243
# Method:                    Least Squares   F-statistic:                     169.3
# Date:                   Tue, 03 Dec 2024   Prob (F-statistic):          1.20e-217
# Time:                           22:21:12   Log-Likelihood:                -4655.1
# No. Observations:                   3680   AIC:                             9326.
# Df Residuals:                       3672   BIC:                             9376.
# Df Model:                              7
# Covariance Type:               nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              7.7992      0.346     22.544      0.000       7.121       8.478
# C(female)[T.1]        -0.4310      0.157     -2.744      0.006      -0.739      -0.123
# C(minority)[T.1.0]    -0.4088      0.163     -2.501      0.012      -0.729      -0.088
# np.log(educ)           0.8756      0.133      6.601      0.000       0.615       1.136
# exper                  0.0557      0.004     15.510      0.000       0.049       0.063
# AFQT                   0.1919      0.021      9.093      0.000       0.151       0.233
# female_educ           -0.0008      0.011     -0.069      0.945      -0.023       0.021
# minority_educ          0.0295      0.012      2.482      0.013       0.006       0.053
# ==============================================================================
# Omnibus:                     1390.028   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9359.859
# Skew:                          -1.641   Prob(JB):                         0.00
# Kurtosis:                      10.091   Cond. No.                         528.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [raw]
# Add your discussion here
#
# This is a strong model because Log-transformed Annual Income addresses the typical right-skewed distribution of income data and makes the model less sensitive to extreme values. It allows an interpretation of coefficients as percentage changes in income. Out of the 10 different approaches I took, this seemed most intuitive and had a greater R sqaured value as well.
#
# Returns to education often exhibit diminishing returns which is why log(educ) is great. AFQT controls for ability, reducing omitted variable bias. Experience captures an important factor when considering annual income. female_educ captures how returns to education differ by gender and minority_educ captures how returns to education differ by minority status
#
# Model performance:
#
# Adjusted R-squared of 0.243 shows a reasonably good performance. Most individual variables are also statistically significant.

# %% [markdown]
# #### Exercise 5: Omitted variables and Measurement errors

# %% [markdown]
# _Research goal_: We want to understand how education affects annual income.

# %% [markdown]
# 1. (a) Provide an example of an omitted variable that we want to include in the regression, but we don't have in the current dataset.  It can be something that data could be collected on, but was left out, or something that is difficult or impossible to collect data on.

# %% [raw]
# Please write your explanation here
#
# The variable Parents' Income isn't in our dataset but would be valuable because parents' income influences both education and future earnings. It shows the family resources available for education. It also reflects neighborhood quality, school quality, and access to educational resources. Very importantly, it indicates social networks that can help in job searches.
#
# It could be collected through surveys and was left out in our case.

# %% [markdown]
# 1. (b) Do you think that by omitting this variable our conclusions about the effect of education on annual income are biased? What direction is the bias (upward or downward)?

# %% [raw]
# Please write your explanation here
#
# Yes our findings are biased.
# I think that Parents' income is positively correlated with education (Cov(education, parent_income) > 0). I also think that Parents' income is positively correlated with the child's income (Beta_2 > 0).
# Since both are positive (OBV > 0), omitting parents' income creates an upward bias. The education coefficient captures not just the true effect of education but also some of the advantageous effects of coming from a higher-income family (We over-estimate the true value).

# %% [markdown]
# 2. The annual income is self-reported. There is measurement error in it. Can you tell me your best guess on the direction of the bias?

# %% [raw]
# Please write your explanation here
#
# My best guess is that the education coefficient has a upward bias. Higher-income individuals (often more educated) usually overstate their income (we discussed this in class), the bias would be upward, exaggerating the effect of education on income.

# %%
# before submitting, run the by clicking the >> button at the top.  Make sure everything runs before you turn it in.
