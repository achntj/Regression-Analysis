# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
hdf = pd.read_excel('Maricopa.xlsx')
hdf_2019 = hdf[hdf['year_sold'] == 2019 ]
hdf_2019
# Out:
#       sale_price  area  pool_area  central_AC  fixtures  garage_count  \
# 1         377500  2919        475           1        11             3
# 6         262500  2477          0           1         9             3
# 8         240000  2139          0           1        11             2
# 26        459900  2087        505           1         6             2
# 35        276000  2016          0           1         8             2
# ...          ...   ...        ...         ...       ...           ...
# 2145      380000  3253        345           1        12             2
# 2153      288500  1861          0           1         7             2
# 2161      315000  1597          0           1         7             2
# 2164      294000  1400          0           1         6             0
# 2170      345000  1968        400           1         8             2
#
#       patio_count  single_story  year_built  year_sold  month_sold  zipcode  \
# ...

# %%
results = smf.ols('sale_price ~ area + pool_area + garage_count', data=hdf_2019).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             sale_price   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.599
# Method:                 Least Squares   F-statistic:                     137.3
# Date:                Tue, 01 Oct 2024   Prob (F-statistic):           4.16e-54
# Time:                        14:28:29   Log-Likelihood:                -3564.9
# No. Observations:                 275   AIC:                             7138.
# Df Residuals:                     271   BIC:                             7152.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     6952.6797   2.11e+04      0.330      0.742   -3.45e+04    4.84e+04
# ...

# %%
results = smf.ols('sale_price ~ area + pool_area + garage_count + city', data=hdf_2019).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             sale_price   R-squared:                       0.742
# Model:                            OLS   Adj. R-squared:                  0.718
# Method:                 Least Squares   F-statistic:                     30.01
# Date:                Tue, 01 Oct 2024   Prob (F-statistic):           4.54e-60
# Time:                        14:28:31   Log-Likelihood:                -3505.5
# No. Observations:                 275   AIC:                             7061.
# Df Residuals:                     250   BIC:                             7151.
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept               -5.485e+04   3.77e+04     -1.456      0.147   -1.29e+05    1.94e+04
# ...
