# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %%
df = pd.read_excel("Maricopa.xlsx")
df
# Out:
#       sale_price  area  pool_area  central_AC  fixtures  garage_count  \
# 0         345000  2015          0           1         7             2
# 1         377500  2919        475           1        11             3
# 2         423039  2044          0           1         7             3
# 3         333341  1754          0           1         7             2
# 4         207000  1680        420           1         8             2
# ...          ...   ...        ...         ...       ...           ...
# 2173      235500  1656        461           1         6             2
# 2174      765000  2571        450           1        11             2
# 2175      465000  2763        500           1        12             2
# 2176      270000  1614          0           1         7             2
# 2177      166000  1738          0           1         6             2
#
#       patio_count  single_story  year_built  year_sold  month_sold  zipcode  \
# ...

# %%
results = smf.ols("sale_price ~ area", data=df).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             sale_price   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     2211.
# Date:                Thu, 07 Nov 2024   Prob (F-statistic):               0.00
# Time:                        14:35:45   Log-Likelihood:                -28330.
# No. Observations:                2178   AIC:                         5.666e+04
# Df Residuals:                    2176   BIC:                         5.668e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3930.8095   6695.297      0.587      0.557   -9199.035    1.71e+04
# ...

# %%
error = np.random.normal(0, np.std(df['sale_price']), size=len(df['sale_price']))
df['price_with_error'] = df['sale_price'] + error

# %%
df
# Out:
#       sale_price  area  pool_area  central_AC  fixtures  garage_count  \
# 0         345000  2015          0           1         7             2
# 1         377500  2919        475           1        11             3
# 2         423039  2044          0           1         7             3
# 3         333341  1754          0           1         7             2
# 4         207000  1680        420           1         8             2
# ...          ...   ...        ...         ...       ...           ...
# 2173      235500  1656        461           1         6             2
# 2174      765000  2571        450           1        11             2
# 2175      465000  2763        500           1        12             2
# 2176      270000  1614          0           1         7             2
# 2177      166000  1738          0           1         6             2
#
#       patio_count  single_story  year_built  year_sold  month_sold  zipcode  \
# ...

# %%
results2 = smf.ols("price_with_error ~ area", data=df).fit()
print(results2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       price_with_error   R-squared:                       0.260
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     765.9
# Date:                Thu, 07 Nov 2024   Prob (F-statistic):          1.06e-144
# Time:                        14:37:29   Log-Likelihood:                -29506.
# No. Observations:                2178   AIC:                         5.902e+04
# Df Residuals:                    2176   BIC:                         5.903e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    456.0223   1.15e+04      0.040      0.968   -2.21e+04     2.3e+04
# ...

# %%
error = np.random.normal(0, np.std(df['area']), size=len(df['area']))
df['area_with_error'] = df['area'] + error
df
# Out:
#       sale_price  area  pool_area  central_AC  fixtures  garage_count  \
# 0         345000  2015          0           1         7             2
# 1         377500  2919        475           1        11             3
# 2         423039  2044          0           1         7             3
# 3         333341  1754          0           1         7             2
# 4         207000  1680        420           1         8             2
# ...          ...   ...        ...         ...       ...           ...
# 2173      235500  1656        461           1         6             2
# 2174      765000  2571        450           1        11             2
# 2175      465000  2763        500           1        12             2
# 2176      270000  1614          0           1         7             2
# 2177      166000  1738          0           1         6             2
#
#       patio_count  single_story  year_built  year_sold  month_sold  zipcode  \
# ...

# %%
results3 = smf.ols("sale_price ~ area_with_error", data=df).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             sale_price   R-squared:                       0.249
# Model:                            OLS   Adj. R-squared:                  0.248
# Method:                 Least Squares   F-statistic:                     720.1
# Date:                Thu, 07 Nov 2024   Prob (F-statistic):          2.90e-137
# Time:                        14:42:49   Log-Likelihood:                -28783.
# No. Observations:                2178   AIC:                         5.757e+04
# Df Residuals:                    2176   BIC:                         5.758e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        1.487e+05   6296.336     23.611      0.000    1.36e+05    1.61e+05
# ...
