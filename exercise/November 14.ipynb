# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %%
df = pd.read_excel("Maricopa.xlsx")
df
# Out:
#       sale_price  area  pool_area  central_AC  fixtures  garage_count  \
# 0         345000  2015          0           1         7             2
# 1         377500  2919        475           1        11             3
# 2         423039  2044          0           1         7             3
# 3         333341  1754          0           1         7             2
# 4         207000  1680        420           1         8             2
# ...          ...   ...        ...         ...       ...           ...
# 2173      235500  1656        461           1         6             2
# 2174      765000  2571        450           1        11             2
# 2175      465000  2763        500           1        12             2
# 2176      270000  1614          0           1         7             2
# 2177      166000  1738          0           1         6             2
#
#       patio_count  single_story  year_built  year_sold  month_sold  zipcode  \
# ...

# %%
results = smf.ols("sale_price ~ area + single_story", data=df).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             sale_price   R-squared:                       0.546
# Model:                            OLS   Adj. R-squared:                  0.545
# Method:                 Least Squares   F-statistic:                     1306.
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):               0.00
# Time:                        13:59:43   Log-Likelihood:                -28235.
# No. Observations:                2178   AIC:                         5.648e+04
# Df Residuals:                    2175   BIC:                         5.649e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -8.785e+04   9122.686     -9.630      0.000   -1.06e+05      -7e+04
# ...

# %%
random = np.random.uniform(0, 1, size=len(df['sale_price']))
df['random'] = random

# %%
df
# Out:
#       sale_price  area  pool_area  central_AC  fixtures  garage_count  \
# 0         345000  2015          0           1         7             2
# 1         377500  2919        475           1        11             3
# 2         423039  2044          0           1         7             3
# 3         333341  1754          0           1         7             2
# 4         207000  1680        420           1         8             2
# ...          ...   ...        ...         ...       ...           ...
# 2173      235500  1656        461           1         6             2
# 2174      765000  2571        450           1        11             2
# 2175      465000  2763        500           1        12             2
# 2176      270000  1614          0           1         7             2
# 2177      166000  1738          0           1         6             2
#
#       patio_count  single_story  year_built  year_sold  month_sold  zipcode  \
# ...

# %%
df = df.drop(df[(df.random < 0.5) & (df.single_story == 1)].index)
df
# Out:
#       sale_price  area  pool_area  central_AC  fixtures  garage_count  \
# 2         423039  2044          0           1         7             3
# 3         333341  1754          0           1         7             2
# 4         207000  1680        420           1         8             2
# 5         305898  2909          0           1        10             2
# 6         262500  2477          0           1         9             3
# ...          ...   ...        ...         ...       ...           ...
# 2168      142900  1423          0           1         7             2
# 2169      295000  2900          0           1        13             3
# 2171      164500  1952          0           1         9             2
# 2174      765000  2571        450           1        11             2
# 2175      465000  2763        500           1        12             2
#
#       patio_count  single_story  year_built  year_sold  month_sold  zipcode  \
# ...

# %%
results2 = smf.ols("sale_price ~ area + single_story", data=df).fit()
print(results2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             sale_price   R-squared:                       0.513
# Model:                            OLS   Adj. R-squared:                  0.513
# Method:                 Least Squares   F-statistic:                     717.6
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):          1.73e-213
# Time:                        13:59:43   Log-Likelihood:                -17735.
# No. Observations:                1363   AIC:                         3.548e+04
# Df Residuals:                    1360   BIC:                         3.549e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -6.235e+04   1.11e+04     -5.609      0.000   -8.42e+04   -4.05e+04
# ...
