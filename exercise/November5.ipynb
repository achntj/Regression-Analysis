# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %%
df = pd.read_excel("Maricopa.xlsx")
df
# Out:
#       sale_price  area  ...             roof  patio_type
# 0         345000  2015  ...    Concrete Tile       Cover
# 1         377500  2919  ...    Concrete Tile       Cover
# 2         423039  2044  ...    Concrete Tile       Cover
# 3         333341  1754  ...    Concrete Tile       Cover
# 4         207000  1680  ...    Concrete Tile       Cover
# ...          ...   ...  ...              ...         ...
# 2173      235500  1656  ...  Asphalt Shingle        Slab
# 2174      765000  2571  ...             Tile       Cover
# 2175      465000  2763  ...    Concrete Tile       Cover
# 2176      270000  1614  ...    Concrete Tile       Cover
# 2177      166000  1738  ...  Asphalt Shingle       Cover
#
# [2178 rows x 17 columns]

# %%
results = smf.ols("sale_price ~ area + garage_count", data=df).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             sale_price   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     1150.
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):               0.00
# Time:                        14:15:11   Log-Likelihood:                -28308.
# No. Observations:                2178   AIC:                         5.662e+04
# Df Residuals:                    2175   BIC:                         5.664e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -1.856e+04   7429.927     -2.498      0.013   -3.31e+04   -3991.389
# ...

# %%
results2 = smf.ols("sale_price ~ area", data=df).fit()
print(results2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             sale_price   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     2211.
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):               0.00
# Time:                        14:15:23   Log-Likelihood:                -28330.
# No. Observations:                2178   AIC:                         5.666e+04
# Df Residuals:                    2176   BIC:                         5.668e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3930.8095   6695.297      0.587      0.557   -9199.035    1.71e+04
# ...

# %%
obv = 138.3707 - 124.9109
obv # without garage count we are over estimating by 13.5
# Out:
# 13.459800000000001

# %%
results3 = smf.ols("garage_count ~ area", data=df).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           garage_count   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.322
# Method:                 Least Squares   F-statistic:                     1034.
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):          6.10e-186
# Time:                        14:22:30   Log-Likelihood:                -2196.7
# No. Observations:                2178   AIC:                             4397.
# Df Residuals:                    2176   BIC:                             4409.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9726      0.041     23.618      0.000       0.892       1.053
# ...

# %%
beta_2 = 23130
gamma = 0.0006
beta_2*gamma
# Out:
# 13.877999999999998
